# %%
import pandas as pd

df = pd.read_csv('data/sonar3.csv', header=None);
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   0
# 1  0.0052  0.0044   0
# 2  0.0095  0.0078   0
# ...

# %%
from tensorflow.keras import models, layers
from sklearn.model_selection import train_test_split

from tensorflow.keras.callbacks import TensorBoard
from time import time

# %%
X = df.iloc[:, :60];
y = df.iloc[:, 60];

# %%
X_train, X_test, y_train, y_test = \
train_test_split(X, y, test_size=0.3, shuffle=True)

# %%
model = models.Sequential();
model.add(layers.Dense(24, input_dim=60, activation='relu'));
model.add(layers.Dense(10, activation='relu'));
model.add(layers.Dense(1, activation='sigmoid'));

# %%
tensorboard = TensorBoard(log_dir='logs\{}'.format(time()));

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']);

# %%
history = model.fit(X_train, y_train, epochs=200, batch_size=10, callbacks=[tensorboard]);
# Out:
# Epoch 1/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0677 - accuracy: 0.9931
# Epoch 2/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9793
# Epoch 3/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0593 - accuracy: 0.9931
# Epoch 4/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0590 - accuracy: 0.9931
# Epoch 5/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0594 - accuracy: 0.9862
# Epoch 6/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0565 - accuracy: 0.9931
# Epoch 7/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0573 - accuracy: 0.9931
# Epoch 8/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0548 - accuracy: 0.9931
# Epoch 9/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0562 - accuracy: 0.9931
# Epoch 10/200
# ...

# %% [markdown]
#  ### log 찍기
#
# from tensorflow.keras.callbacks import TensorBoard \
# from time import time
#
# tensorboard = TensorBoard(log_dir='logs\{}'.format(time())); \
# model.fit() 안에 callbacks=[tensorboard]
#
# cmd가서 tensorboard --logdir=.logs 실행

# %%
score = model.evaluate(X_test, y_test)
print('Test Accuracy: ', score[1]) # score[0]는 손실값, score[1]은 정확도
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4964 - accuracy: 0.7619
# Test Accuracy:  0.761904776096344

# %%
# 훈련된 모델을 저장하기
# layer와 parameter 정보 들어간 파일(계층형 데이터 저장 가능한 파일)
# model.save('data/mineral.hdf5')

# %%
# 변수 내용 삭제
# mdel model

# %%
# mscore = model.evaluate(X_test, y_test)

# %%
# 모델 불러오기
# mmodel = models.load_model('data/mineral.hdf5')

# %%
# 불러온 모델 확인
# mscore = model.evaluate(X_test, y_test)
# mprint('Test Accuracy: ', score[1])
